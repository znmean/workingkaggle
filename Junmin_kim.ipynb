# %%
# %matplotlib notebook
import pandas as pd
#import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer

# %%
df = pd.read_csv('../input/train.csv')

# %% [markdown]
# ## Check train data

# %%
df[:3].T
# Out:
#                                                               0  \
# id                                                            0
# qid1                                                          1
# qid2                                                          2
# question1     What is the step by step guide to invest in sh...
# question2     What is the step by step guide to invest in sh...
# is_duplicate                                                  0
#
#                                                               1  \
# id                                                            1
# qid1                                                          3
# qid2                                                          4
# question1     What is the story of Kohinoor (Koh-i-Noor) Dia...
# question2     What would happen if the Indian government sto...
# is_duplicate                                                  0
#
#                                                               2
# id                                                            2
# qid1                                                          5
# qid2                                                          6
# question1     How can I increase the speed of my internet co...
# question2     How can Internet speed be increased by hacking...
# is_duplicate                                                  0

# %%
df.loc[2,'question1'],df.loc[2,'question2'],
# Out:
# ('How can I increase the speed of my internet connection while using a VPN?',
#  'How can Internet speed be increased by hacking through DNS?')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
# id              404290 non-null int64
# qid1            404290 non-null int64
# qid2            404290 non-null int64
# question1       404290 non-null object
# question2       404288 non-null object
# is_duplicate    404290 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %% [markdown]
# there are 2 null object in q2. fill that

# %%
df['question2'] = df['question2'].fillna('')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
# id              404290 non-null int64
# qid1            404290 non-null int64
# qid2            404290 non-null int64
# question1       404290 non-null object
# question2       404290 non-null object
# is_duplicate    404290 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %% [markdown]
# ## transform
# use tfidf vectorizer (without using tf-idf)

# %%
vect = TfidfVectorizer(use_idf=False)

# %%
# %time vect.fit(df.question1.append(df.question2))
# Out:
# CPU times: user 18.7 s, sys: 667 ms, total: 19.4 s
# Wall time: 40.4 s
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=False,
#         vocabulary=None)

# %%
# %time df['q1_vect'] = list(vect.transform(df.question1))
# Out:
# CPU times: user 1min 16s, sys: 827 ms, total: 1min 17s
# Wall time: 1min 23s

# %%
# %time df['q2_vect'] = list(vect.transform(df['question2']))
# Out:
# CPU times: user 1min 18s, sys: 775 ms, total: 1min 19s
# Wall time: 1min 29s

# %%
def question_cosine_distance(df):
    return cosine_distances(df.q1_vect, df.q2_vect)[0]

# %%
# %time df['tf_nonstop_dist'] = df.apply(question_cosine_distance, axis=1)['id']
# Out:
# CPU times: user 12min 28s, sys: 0 ns, total: 12min 28s
# Wall time: 12min 32s

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
plt.figure(figsize=(12, 8))
plt.subplot(1,2,1)
sns.violinplot(x = 'is_duplicate', y = 'cos_dist', data = df[0:50000])
plt.subplot(1,2,2)
sns.distplot(df[df['is_duplicate'] == 1.0]['cos_dist'][0:10000], color = 'green')
sns.distplot(df[df['is_duplicate'] == 0.0]['cos_dist'][0:10000], color = 'red')
# Out:
# <img src="data:image/png;base64,...">
# /root/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
cosine_distances(df.loc[0,'q1_vect'],df.loc[0,'q2_vect'])
# Out:
# array([[ 0.05508882]])

# %%
q1vect_example = vect.transform(df[:1].question1)
q1vect_example

# %%
df['cos_dist'].hist()
# Out:
# <img src="data:image/png;base64,...">

# %%
df[df.is_duplicate==0]['cos_dist'].hist()

# %% [markdown]
# ## transform (tf-idf)

# %%
vect = TfidfVectorizer(use_idf=True)
# %time vect.fit(df.question1.append(df.question2))
# Out:
# CPU times: user 22.4 s, sys: 133 ms, total: 22.6 s
# Wall time: 24.3 s
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
# %time df['q1_vect'] = list(vect.transform(df.question1))
# %time df['q2_vect'] = list(vect.transform(df['question2']))
# %time df['tfidf_nonstop_dist'] = df.apply(question_cosine_distance, axis=1)['id']
# Out:
# CPU times: user 1min 17s, sys: 585 ms, total: 1min 18s
# Wall time: 1min 21s
# CPU times: user 1min 15s, sys: 661 ms, total: 1min 16s
# Wall time: 1min 35s
# CPU times: user 12min 13s, sys: 0 ns, total: 12min 13s
# Wall time: 12min 32s

# %%
plt.figure(figsize=(12, 8))
plt.subplot(1,2,1)
sns.violinplot(x = 'is_duplicate', y = 'cos_dist', data = df)
plt.subplot(1,2,2)
sns.distplot(df[df['is_duplicate'] == 1.0]['cos_dist'], color = 'green')
sns.distplot(df[df['is_duplicate'] == 0.0]['cos_dist'], color = 'red')
# Out:
# <img src="data:image/png;base64,...">
# /root/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
vect = TfidfVectorizer(use_idf=True, stop_words='english')
# %time vect.fit(df.question1.append(df.question2))
# %time df['q1_vect'] = list(vect.transform(df.question1))
# %time df['q2_vect'] = list(vect.transform(df['question2']))
# %time df['tfidf_stop_dist'] = df.apply(question_cosine_distance, axis=1)['id']

#plot
plt.figure(figsize=(12, 8))
plt.subplot(1,2,1)
sns.violinplot(x = 'is_duplicate', y = 'cos_dist', data = df)
plt.subplot(1,2,2)
sns.distplot(df[df['is_duplicate'] == 1.0]['cos_dist'], color = 'green')
sns.distplot(df[df['is_duplicate'] == 0.0]['cos_dist'], color = 'red')
# Out:
# CPU times: user 21.2 s, sys: 0 ns, total: 21.2 s
# Wall time: 21.6 s
# CPU times: user 1min 15s, sys: 539 ms, total: 1min 15s
# Wall time: 1min 18s
# CPU times: user 1min 15s, sys: 628 ms, total: 1min 16s
# Wall time: 1min 17s
# CPU times: user 12min 27s, sys: 448 ms, total: 12min 27s
# Wall time: 13min 5s
# <img src="data:image/png;base64,...">
# /root/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
vect = TfidfVectorizer(use_idf=False, stop_words='english')
# %time vect.fit(df.question1.append(df.question2))
# %time df['q1_vect'] = list(vect.transform(df.question1))
# %time df['q2_vect'] = list(vect.transform(df['question2']))
# %time df['idf_stop_dist'] = df.apply(question_cosine_distance, axis=1)['id']

#plot
plt.figure(figsize=(12, 8))
plt.subplot(1,2,1)
sns.violinplot(x = 'is_duplicate', y = 'cos_dist', data = df)
plt.subplot(1,2,2)
sns.distplot(df[df['is_duplicate'] == 1.0]['cos_dist'], color = 'green')
sns.distplot(df[df['is_duplicate'] == 0.0]['cos_dist'], color = 'red')
# Out:
# CPU times: user 20.7 s, sys: 136 ms, total: 20.9 s
# Wall time: 22.7 s
# CPU times: user 1min 14s, sys: 481 ms, total: 1min 14s
# Wall time: 1min 18s
# CPU times: user 1min 13s, sys: 534 ms, total: 1min 14s
# Wall time: 1min 16s
# CPU times: user 12min 35s, sys: 491 ms, total: 12min 35s
# Wall time: 13min 52s
# <img src="data:image/png;base64,...">
# /root/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
from sklearn.metrics import log_loss

# %%
df_back = df.copy(deep=True)

# %%
#del(df['cos_dist'])
del(df['q1_vect'])
del(df['q2_vect'])

# %%
df[:3].T
# Out:
#                                                                     0  \
# id                                                                  0
# qid1                                                                1
# qid2                                                                2
# question1           What is the step by step guide to invest in sh...
# question2           What is the step by step guide to invest in sh...
# is_duplicate                                                        0
# tf_nonstop_dist                                             0.0550888
# tfidf_nonstop_dist                                          0.0214848
# tfidf_stop_dist                                             0.0182158
# idf_stop_dist                                                0.057191
#
#                                                                     1  \
# id                                                                  1
# qid1                                                                3
# qid2                                                                4
# question1           What is the story of Kohinoor (Koh-i-Noor) Dia...
# question2           What would happen if the Indian government sto...
# is_duplicate                                                        0
# tf_nonstop_dist                                              0.416667
# tfidf_nonstop_dist                                           0.250245
# tfidf_stop_dist                                               0.20806
# idf_stop_dist                                                0.367544
#
#                                                                     2
# id                                                                  2
# qid1                                                                5
# qid2                                                                6
# question1           How can I increase the speed of my internet co...
# question2           How can Internet speed be increased by hacking...
# is_duplicate                                                        0
# tf_nonstop_dist                                              0.634852
# tfidf_nonstop_dist                                           0.745323
# tfidf_stop_dist                                              0.723911
# idf_stop_dist                                                0.634852

# %%
training_fields = ['tf_nonstop_dist','tfidf_nonstop_dist','tfidf_stop_dist','idf_stop_dist']

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss='log')

# %%
clf.fit(df[training_fields], df['is_duplicate'])
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)

# %%
df['predict_proba1'] = list(clf.predict_proba(df[training_fields]))

# %%
df['predict_proba1'] = df['predict_proba1'].apply(lambda x:x[1])

# %%
log_loss(df['is_duplicate'], df['predict_proba1'])
# Out:
# 0.5651101976322126
