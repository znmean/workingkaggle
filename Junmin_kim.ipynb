# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.DataFrame([1,2,3,4,5]).plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
pd.DataFrame([1,2,3,4,5])
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# # 안녕하세요 한글
